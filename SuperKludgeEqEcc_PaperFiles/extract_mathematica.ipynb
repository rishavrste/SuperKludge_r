# %%
pip install sympy
# Out:
# DEPRECATION: Loading egg at /home/shubham/miniconda3/envs/few2_april/lib/python3.12/site-packages/lisaanalysistools-1.0.13-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/shubham/miniconda3/envs/few2_april/lib/python3.12/site-packages/fastlisaresponse-1.0.11-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 17.2 MB/s eta 0:00:0031m16.8 MB/s eta 0:00:01
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sympy.parsing.mathematica import parse_mathematica

with open("/home/shubham/SuperKludge/version0.2/y0.m", "r") as file:
    math_expr = file.read()

sympy_expr = parse_mathematica(math_expr)
print(sympy_expr)
# Out:
# (-24*Chi1*yPhi**2 - 3*sqrt(-2*Chi1**2*yPhi**4*(391*yPhi**2 + 60) + 9*yPhi**2*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4)))/(-36*lamb + yPhi**2*(46*Chi1**2 - 315))

# %%
with open("/home/shubham/SuperKludge/version0.2/y1.m", "r") as file:
    math_expr = file.read()

sympy_expr = parse_mathematica(math_expr)
print(sympy_expr)
# Out:
# 2*yPhi**2*(15*Chi1 - 9*Chi2 + sqrt(-2*Chi1**2*yPhi**4*(391*yPhi**2 + 60) + 9*yPhi**2*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4))*(252*Chi1**2 - 108*Chi1*Chi2 - 234*lamb + yPhi**2*(1880*Chi1**2 - 765*Chi1*Chi2 - 4113) - 486)/(2*Chi1**2*yPhi**2*(391*yPhi**2 + 60) - 9*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4)))/(-36*lamb + yPhi**2*(46*Chi1**2 - 315)) - 6*yPhi**2*(8*Chi1*yPhi**2 + sqrt(-2*Chi1**2*yPhi**4*(391*yPhi**2 + 60) + 9*yPhi**2*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4)))*(62*Chi1**2 - 30*Chi1*Chi2 - 81)/(-36*lamb + yPhi**2*(46*Chi1**2 - 315))**2

# %%
with open("/home/shubham/SuperKludge/version0.2/y2.m", "r") as file:
    math_expr = file.read()

sympy_expr = parse_mathematica(math_expr)
print(sympy_expr)
# Out:
# -2*yPhi**4*(15*Chi1 - 9*Chi2 + sqrt(-2*Chi1**2*yPhi**4*(391*yPhi**2 + 60) + 9*yPhi**2*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4))*(252*Chi1**2 - 108*Chi1*Chi2 - 234*lamb + yPhi**2*(1880*Chi1**2 - 765*Chi1*Chi2 - 4113) - 486)/(2*Chi1**2*yPhi**2*(391*yPhi**2 + 60) - 9*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4)))*(-124*Chi1**2 + 60*Chi1*Chi2 + 162)/(-36*lamb + yPhi**2*(46*Chi1**2 - 315))**2 + 6*yPhi**2*(8*Chi1*yPhi**2 + sqrt(-2*Chi1**2*yPhi**4*(391*yPhi**2 + 60) + 9*yPhi**2*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4)))*(-36*lamb*(Chi1 + Chi2)*(5*Chi1 - 9*Chi2) + yPhi**2*(7918*Chi1**4 - 21663*Chi1**2 + 4*Chi1*Chi2*(2745 - 1906*Chi1**2) + 63*Chi2**2*(22*Chi1**2 + 45) + 13122))/(36*lamb + yPhi**2*(315 - 46*Chi1**2))**3 + (24*yPhi**2*(Chi1 - Chi2) - 36*sqrt(-2*Chi1**2*yPhi**4*(391*yPhi**2 + 60) + 9*yPhi**2*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4))*(-24*(yPhi**6*(1880*Chi1**2 - 765*Chi1*Chi2 - 4113) - 18*yPhi**4*(-14*Chi1**2 + 6*Chi1*Chi2 + 13*lamb + 27))**2 - (yPhi**6*(1357*Chi1**2 - 576*Chi1*Chi2 + 459*C
# ...

# %%
with open("/home/shubham/SuperKludge/version0.2/es0.m", "r") as file:
    math_expr = file.read()

sympy_expr = parse_mathematica(math_expr)
print(sympy_expr)
# Out:
# (16*Chi1*sqrt(-2*Chi1**2*yPhi**4*(391*yPhi**2 + 60) + 9*yPhi**2*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4)) - 144*lamb + 34*yPhi**4*(23*Chi1**2 - 81) - 4*yPhi**2*(-14*Chi1**2 + 153*lamb + 9) + 144)/(9*(17*yPhi**2 + 4)**2)

# %%
with open("/home/shubham/SuperKludge/version0.2/es1.m", "r") as file:
    math_expr = file.read()

sympy_expr = parse_mathematica(math_expr)
print(sympy_expr)
# Out:
# 104*yPhi**2*(8*Chi1*sqrt(-2*Chi1**2*yPhi**4*(391*yPhi**2 + 60) + 9*yPhi**2*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4)) - 72*lamb + 17*yPhi**4*(23*Chi1**2 - 81) - 2*yPhi**2*(-14*Chi1**2 + 153*lamb + 9) + 72)/(27*(17*yPhi**2 + 4)**3) + (4*yPhi**4*(-1880*Chi1**2 + 765*Chi1*Chi2 + 2124) + 24*yPhi**2*(-22*Chi1**2 + 6*Chi1*Chi2 + 39*lamb + 3) + 4*sqrt(-2*Chi1**2*yPhi**4*(391*yPhi**2 + 60) + 9*yPhi**2*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4))*(432*lamb*(5*Chi1 - 3*Chi2) + yPhi**4*(Chi1*(-26770*Chi1**2 + 13158*Chi1*Chi2 + 113229) - 48195*Chi2) + 36*yPhi**2*(Chi1*(-106*Chi1**2 + 307*lamb + 633) - 9*Chi2*(-6*Chi1**2 + 17*lamb + 35)))/(2*Chi1**2*yPhi**2*(391*yPhi**2 + 60) - 9*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4)))/(3*(51*yPhi**2 + 12)**2)

# %%
with open("/home/shubham/SuperKludge/version0.2/es2.m", "r") as file:
    math_expr = file.read()

sympy_expr = parse_mathematica(math_expr)
print(sympy_expr)
# Out:
# 1352*yPhi**4*(8*Chi1*sqrt(-2*Chi1**2*yPhi**4*(391*yPhi**2 + 60) + 9*yPhi**2*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4)) - 72*lamb + 17*yPhi**4*(23*Chi1**2 - 81) - 2*yPhi**2*(-14*Chi1**2 + 153*lamb + 9) + 72)/(27*(17*yPhi**2 + 4)**4) + 52*yPhi**2*(4*yPhi**4*(-1880*Chi1**2 + 765*Chi1*Chi2 + 2124) + 24*yPhi**2*(-22*Chi1**2 + 6*Chi1*Chi2 + 39*lamb + 3) + 4*sqrt(-2*Chi1**2*yPhi**4*(391*yPhi**2 + 60) + 9*yPhi**2*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4))*(432*lamb*(5*Chi1 - 3*Chi2) + yPhi**4*(Chi1*(-26770*Chi1**2 + 13158*Chi1*Chi2 + 113229) - 48195*Chi2) + 36*yPhi**2*(Chi1*(-106*Chi1**2 + 307*lamb + 633) - 9*Chi2*(-6*Chi1**2 + 17*lamb + 35)))/(2*Chi1**2*yPhi**2*(391*yPhi**2 + 60) - 9*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4)))/(3*(51*yPhi**2 + 12)**3) + (48*Chi1*yPhi**2*(Chi1 + Chi2) + 24*Chi1*sqrt(-2*Chi1**2*yPhi**4*(391*yPhi**2 + 60) + 9*yPhi**2*(4*lamb + 35*yPhi**2)*(17*yPhi**2 + 4))*(-4*yPhi**4*(-252*Chi1**2 + 108*Chi1*Chi2 + 234*lamb + yPhi**2*(-1880*Chi1**2 + 765*Chi1*Chi2 + 4113) + 486)**2/(9
# ...
