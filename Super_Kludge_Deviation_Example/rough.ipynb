# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

# %%
import sampler
import numpy as np
from sampler import parse_arguments, Sampler
# !python sampler.py "/Users/rishavagrawal/programs/Results/first_sampling_data.txt" "/Users/rishavagrawal/programs/Results/truth_first_sampling_data.txt" "/Users/rishavagrawal/programs/Results/Covariance_first_sampling_data.txt" True "/Users/rishavagrawal/programs/Results/output_first_try" 5 200 20000
# Out:
# ranges
#  [[5.99920088 6.00079765]
#  [0.9995823  1.00041729]
#  [0.79846358 0.80153642]
#  [8.99073356 9.00926644]
#  [0.39966618 0.40033382]
#  [0.97416969 1.02583031]
#  [0.44924116 0.55075884]
#  [0.95702394 1.04297606]
#  [0.36648852 0.43351148]
#  [0.48060655 0.51939345]]
# -1.5133619702008148e-11
# -1.51472222650711e-11
# -1.5443413343656938e-11
# -1.5320329544360266e-11
# -1.5707960207026342e-11
# -1.5881062067548338e-11
# -1.522530944378467e-11
# -1.5724282977755506e-11
# -1.4931889285072975e-11
# -1.542929749840162e-11
# -1.572320519582831e-11
# -1.5630080353943207e-11
# -1.5146399533176967e-11
# -1.5567547400933102e-11
# -1.55224584988899e-11
# -1.5435747571361406e-11
# -1.538117536387739e-11
# -1.5233341865245265e-11
# -1.581315927375002e-11
# -1.5365607952817617e-11
# -1.5519375925241068e-11
# -1.5370638060412458e-11
# -1.5241138368302043e-11
# -1.5164066348805043e-11
# ^C

# %%
np.loadtxt("/Users/rishavagrawal/programs/Results/truth_first_sampling_data.txt")
# Out:
# array([1.e+06, 1.e+01, 8.e-01, 9.e+00, 4.e-01, 1.e+00, 5.e-01, 1.e+00,
#        4.e-01, 5.e-01])
